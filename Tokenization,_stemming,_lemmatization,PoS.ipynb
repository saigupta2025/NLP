# %% [markdown]
# <a href="https://colab.research.google.com/github/saigupta2025/NLP/blob/main/Tokenization%2C_stemming%2C_lemmatization%2CPoS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **TOKENIZATION**

# %%
text= "The recipe calls for 3 cups of flour, 2 eggs, and 1/2 teaspoon of salt! it also needs 4 tablespoons of butter! Did you know that the store opens at 8:00 AM sharp on July 1st? I can't wait!"

# %%
text.split(" ")
# Out:
# ['The',
#  'recipe',
#  'calls',
#  'for',
#  '3',
#  'cups',
#  'of',
#  'flour,',
#  '2',
#  'eggs,',
#  'and',
#  '1/2',
#  'teaspoon',
#  'of',
#  'salt!',
#  'it',
#  'also',
#  'needs',
#  '4',
#  'tablespoons',
#  'of',
#  'butter!',
#  'Did',
#  'you',
#  'know',
#  'that',
#  'the',
#  'store',
#  'opens',
#  'at',
#  '8:00',
#  'AM',
#  'sharp',
#  'on',
#  'July',
#  '1st?',
#  'I',
#  "can't",
#  'wait!']

# %%
import nltk
from nltk import sent_tokenize, word_tokenize
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
# word_tokenization
word_tokenization = word_tokenize(text)
print(word_tokenization)
# Out:
# ['The', 'recipe', 'calls', 'for', '3', 'cups', 'of', 'flour', ',', '2', 'eggs', ',', 'and', '1/2', 'teaspoon', 'of', 'salt', '!', 'it', 'also', 'needs', '4', 'tablespoons', 'of', 'butter', '!', 'Did', 'you', 'know', 'that', 'the', 'store', 'opens', 'at', '8:00', 'AM', 'sharp', 'on', 'July', '1st', '?', 'I', 'ca', "n't", 'wait', '!']

# %%
# sentense tokenization
sentense_tokenization = sent_tokenize(text)
print(sentense_tokenization)
# Out:
# ['The recipe calls for 3 cups of flour, 2 eggs, and 1/2 teaspoon of salt!', 'it also needs 4 tablespoons of butter!', 'Did you know that the store opens at 8:00 AM sharp on July 1st?', "I can't wait!"]

# %% [markdown]
# # **STEMMING**

# %%
from nltk.stem import PorterStemmer
ps= PorterStemmer()
text= "The recipe calling for 3 cups of flour, 2 eggs, and 1/2 teaspoon of salt! it also needs 4 tablespoons of butter! Did yours know that the store opens at 8:00 AM sharped on July 1st? I can't waiting!"
print(ps.stem("eating"))
print(ps.stem("having"))
print(ps.stem("cooked"))
print(ps.stem("bananas"))
print(ps.stem("wedding")) # feels like plural

# print(ps.stem(text))  # is it stemmed ??
word_tokenization = word_tokenize(text)
stemmed_text= " ".join(ps.stem(word) for word in word_tokenization)
print(stemmed_text)
# Out:
# eat
# have
# cook
# banana
# wed
# the recip call for 3 cup of flour , 2 egg , and 1/2 teaspoon of salt ! it also need 4 tablespoon of butter ! did your know that the store open at 8:00 am sharp on juli 1st ? i ca n't wait !

# %% [markdown]
# # **LEMMATIZATION**

# %%
import nltk
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt')
lemmatizer= WordNetLemmatizer()
print(lemmatizer.lemmatize("studies" ))
print(lemmatizer.lemmatize("feet"))
print(lemmatizer.lemmatize("children"))
print(lemmatizer.lemmatize("mice"))
print(lemmatizer.lemmatize("worst"))
print(lemmatizer.lemmatize("booked"))
text= "The recipe calling for 3 cups of flour, 2 eggs, 2 mice and 1/2 teaspoon of salt! it also needs 4 tablespoons of butter! Did yours know that the store opens at 8:00 AM sharped on July 1st? I can't waiting!"

word_tokenization = word_tokenize(text)

lemmatized_text= " ".join(lemmatizer.lemmatize(word) for word in word_tokenization)
print(lemmatized_text)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# study
# foot
# child
# mouse
# worst
# booked
# The recipe calling for 3 cup of flour , 2 egg , 2 mouse and 1/2 teaspoon of salt ! it also need 4 tablespoon of butter ! Did yours know that the store open at 8:00 AM sharped on July 1st ? I ca n't waiting !

# %% [markdown]
# # PoS **Tagging**

# %% [markdown]
# https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html

# %%
from nltk import pos_tag

# %%
pos_tag(["asia", "fighting"])
# Out:
# [('asia', 'NN'), ('fighting', 'VBG')]

# %%
text= "The recipe calling for 3 cups of flour, 2 eggs, 2 mice and 1/2 teaspoon of salt! it also needs 4 tablespoons of butter! Did yours know that the store opens at 8:00 AM sharped on July 1st? I can't waiting!"

word_tokenization = word_tokenize(text)

pos_tag(word_tokenization)  # punctuations are denoted as just dots
# Out:
# [('The', 'DT'),
#  ('recipe', 'NN'),
#  ('calling', 'VBG'),
#  ('for', 'IN'),
#  ('3', 'CD'),
#  ('cups', 'NNS'),
#  ('of', 'IN'),
#  ('flour', 'NN'),
#  (',', ','),
#  ('2', 'CD'),
#  ('eggs', 'NNS'),
#  (',', ','),
#  ('2', 'CD'),
#  ('mice', 'NN'),
#  ('and', 'CC'),
#  ('1/2', 'CD'),
#  ('teaspoon', 'NN'),
#  ('of', 'IN'),
#  ('salt', 'NN'),
#  ('!', '.'),
#  ('it', 'PRP'),
#  ('also', 'RB'),
#  ('needs', 'VBZ'),
#  ('4', 'CD'),
#  ('tablespoons', 'NNS'),
#  ('of', 'IN'),
#  ('butter', 'NN'),
#  ('!', '.'),
#  ('Did', 'NNP'),
#  ('yours', 'VB'),
#  ('know', 'VB'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('store', 'NN'),
#  ('opens', 'VBZ'),
#  ('at', 'IN'),
#  ('8:00', 'CD'),
#  ('AM', 'NNP'),
#  ('sharped', 'VBD'),
#  ('on', 'IN'),
#  ('July', 'NNP'),
#  ('1st', 'CD'),
#  ('?', '.'),
#  ('I', 'PRP'),
#  ('ca', 'MD'),
#  ("n't", 'RB'),
#  ('waiting', 'VBG'),
#  ('!', '.')]

# %%
import nltk
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer

nltk.download('averaged_perceptron_tagger_eng')

lemmatizer = WordNetLemmatizer()

# Function to convert Penn Treebank POS tags to WordNet POS tags
def get_wordnet_pos(treebank_tag):
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN # Default to noun

def lemmatize_sentence(sentence):
    # Tokenize the sentence and get POS tags
    word_pos = nltk.pos_tag(nltk.word_tokenize(sentence))
    lemmatized_words = []

    for word, tag in word_pos:
        # Lemmatize using the correct WordNet POS tag
        lemma = lemmatizer.lemmatize(word, get_wordnet_pos(tag))
        lemmatized_words.append(lemma)

    return " ".join(lemmatized_words)

# Example:
sentence = "The cats were running faster than the dogs."
lemmatized_text = lemmatize_sentence(sentence)
print(f"Original Text: {sentence}")
print(f"Lemmatized Text: {lemmatized_text}")
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# Original Text: The cats were running faster than the dogs.
# Lemmatized Text: The cat be run faster than the dog .
